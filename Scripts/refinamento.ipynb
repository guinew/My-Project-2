# %%
import duckdb

# %%
con = duckdb.connect(database='dados_duckdb.db', read_only=False)

# %%
df = con.execute('SELECT * FROM produtos').fetchdf()
df.head(10)
# Out:
#       id     nm_produto id_categoria  id_fornecedor  vl_preco
# 0  10001       PARAFUSO         BT10            100     100.0
# 1  10002        MARTELO         BT50            100    1500.0
# 2  10003  CHAVE INGLESA         BT10            100      50.0
# 3  10004        ALICATE         BT20            100     200.0
# 4  10005        SERROTE         BT30            100       0.0

# %%
df2 = df.drop(columns=['id_categoria', 'id_fornecedor'])
df2.head(10)
# Out:
#       id     nm_produto  vl_preco
# 0  10001       PARAFUSO     100.0
# 1  10002        MARTELO    1500.0
# 2  10003  CHAVE INGLESA      50.0
# 3  10004        ALICATE     200.0
# 4  10005        SERROTE       0.0

# %%
con.execute('''
            CREATE TABLE IF NOT EXISTS dim_produtos (
            id_produto BIGINT,
            nm_produto TEXT,
            vl_produto FLOAT
            )
            
            
            
            ''')

# %%
df_dim = con.execute('INSERT INTO dim_produtos SELECT * from df2')

# %%
df_dim = con.execute('SELECT * FROM dim_produtos').fetchdf()
df_dim.head(10)
# Out:
#    id_produto     nm_produto  vl_produto
# 0       10001       PARAFUSO       100.0
# 1       10002        MARTELO      1500.0
# 2       10003  CHAVE INGLESA        50.0
# 3       10004        ALICATE       200.0
# 4       10005        SERROTE         0.0
